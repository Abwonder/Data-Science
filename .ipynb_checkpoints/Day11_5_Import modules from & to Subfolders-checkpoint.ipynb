# %% [markdown]
# ### Importing module from different subfolder into each other

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Above details

import os, sys
from os.path import abspath, dirname, join

## its application
sys.path.insert(0, abspath(join(dirname(__file__), "..")))

# %%
##
