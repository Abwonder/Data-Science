# %% [markdown]
# ## Firstly go to the online to get mongdb cloud version === https://www.mongodb.com/
# ## Secondly, use it try for free
# ![image.png](attachment:27864299-fe32-4ca7-8b96-31175d2c122e.png)
#
# ## Thirdly, sign up and do the configuration
#
# ![image.png](attachment:69dfd11b-0264-4a91-b830-d839f118679f.png)
#
# ![image.png](attachment:52e74f52-4c45-4811-af55-959b833a89db.png)
#
# ![image.png](attachment:d5541992-5a97-4124-9257-fa481639e2e3.png)
# ![image.png](attachment:6cfef823-bbd0-4cf2-aede-855b331f9798.png)
#
#
#
#
# ![image.png](attachment:4ffa5359-f62b-4ac2-97ad-7490cb26c40a.png)

# %% [markdown]
# ## others are simple simply use online materials

# %%
import pymongo   ## this has to be imported, library handling mongdb python
client = pymongo.MongoClient("mongodb+srv://Abioyepwskills:Abpwskills@cluster0.p8luxch.mongodb.net/?retryWrites=true&w=majority")
db = client.test
# note: No pymongo on my system, install !!!

# %%
pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 3.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 4.9 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
client
# Out:
# MongoClient(host=['ac-pnge24d-shard-00-00.p8luxch.mongodb.net:27017', 'ac-pnge24d-shard-00-01.p8luxch.mongodb.net:27017', 'ac-pnge24d-shard-00-02.p8luxch.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-kjgcpa-shard-0', tls=True)

# %% [markdown]
# ### mongodb is a file/document base data system, implying data data are stored as dictionary
#
# ### it stores data as collection not table as it is in sql and inside the collection document will now be store no structure is expected!!!!

# %%
client = pymongo.MongoClient("mongodb+srv://Abioyepwskills:Abpwskills@cluster0.p8luxch.mongodb.net/?retryWrites=true&w=majority")

# %%
client
# Out:
# MongoClient(host=['ac-pnge24d-shard-00-00.p8luxch.mongodb.net:27017', 'ac-pnge24d-shard-00-01.p8luxch.mongodb.net:27017', 'ac-pnge24d-shard-00-02.p8luxch.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-kjgcpa-shard-0', tls=True)

# %%
db = client['pwskills']  ## this is database created and inside I can now create collections

# %%
coll_create = db["my_record"]  ##### creating my first collection: named pwskills!!!, , is liken to a table

# %%
### Note it does support structured data
data = {"name" : "sudh",
        "class" : "data science masters ",
        "timing " : "flexi"
}   ### notation here is called json  == Java Script Object Notation or Document : this are the standard terms!!!

# %%
coll_create.insert_one(data)  ### insert is use to input the created data into the collection

# %%
data1 = {"mail_id" : "sudh@gmail.com",
         "phone_number" :2343243242
}

# %%
coll_create.insert_one(data1)

# %%
data2 = {"list_course" : ["data science masters " , "web dev " , "java with DSA"],
        "mentor" : ["sudhanshu" , "anurag" , "hyder"]}

# %%
coll_create.insert_one(data2)

# %%
 data3 = [
  { "name": "Amy", "address": "Apple st 652" },
  { "name": "Hannah", "address": "Mountain 21" },
  { "name": "Michael", "address": "Valley 345" },
  { "name": "Sandy", "address": "Ocean blvd 2" },
  { "name": "Betty", "address": "Green Grass 1" },
  { "name": "Richard", "address": "Sky st 331" },
  { "name": "Susan", "address": "One way 98" },
  { "name": "Vicky", "address": "Yellow Garden 2" },
  { "name": "Ben", "address": "Park Lane 38" },
  { "name": "William", "address": "Central st 954" },
  { "name": "Chuck", "address": "Main Road 989" },
  { "name": "Viola", "address": "Sideway 1633" }
]

# %%
coll_create.insert_many(data3)

# %%
data4 = {
 "name": "notebook",
 "qty": 50,
 "rating": [ { "score": 8 }, { "score": 9 } ],
 "size": { "height": 11, "width": 8.5, "unit": "in" },
 "status": "A",
 "tags": [ "college-ruled", "perforated"]
}

# %%
coll_create.insert_one(data4)

# %%
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

# %%
coll_create.insert_many(list_of_records)

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('63ef080c4d1367f0ea41c25b'), 'name': 'sudh', 'class': 'data science masters ', 'timing ': 'flexi'}
# {'_id': ObjectId('63ef08cc4d1367f0ea41c25c'), 'mail_id': 'sudh@gmail.com', 'phone_number': 2343243242}
# {'_id': ObjectId('63ef09484d1367f0ea41c25d'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('63ef09904d1367f0ea41c25e'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('63ef09904d1367f0ea41c25f'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('63ef09904d1367f0ea41c260'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('63ef09904d1367f0ea41c261'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('63ef09904d1367f0ea41c262'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('63ef09904d1367f0ea41c263'), 'name': 'Richard', 'address': 'Sky st 331'}
# ...

# %%
random_data = [
    {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'XYZ'},
    {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'ABC'},
    {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'PQR'},
]

# %%
coll_create.insert_many(random_data)

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('63ef080c4d1367f0ea41c25b'), 'name': 'sudh', 'class': 'data science masters ', 'timing ': 'flexi'}
# {'_id': ObjectId('63ef08cc4d1367f0ea41c25c'), 'mail_id': 'sudh@gmail.com', 'phone_number': 2343243242}
# {'_id': ObjectId('63ef09484d1367f0ea41c25d'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('63ef09904d1367f0ea41c25e'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('63ef09904d1367f0ea41c25f'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('63ef09904d1367f0ea41c260'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('63ef09904d1367f0ea41c261'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('63ef09904d1367f0ea41c262'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('63ef09904d1367f0ea41c263'), 'name': 'Richard', 'address': 'Sky st 331'}
# ...

# %%
coll_create.find_one()
# Out:
# {'_id': ObjectId('63ef080c4d1367f0ea41c25b'),
#  'name': 'sudh',
#  'class': 'data science masters ',
#  'timing ': 'flexi'}

# %%
for i in coll_create.find({'companyName': 'iNeuron'}):
    print(i)
# Out:
# {'_id': ObjectId('63ef09ec4d1367f0ea41c26b'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('63ef09ec4d1367f0ea41c26c'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('63ef09ec4d1367f0ea41c26d'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'XYZ'}
# {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'PQR'}

# %%
for i in coll_create.find({'_id' : {'$gte' : '4'}}):
    print(i)
# Out:
# {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'PQR'}

# %%
coll_create.update_many({'companyName': 'iNeuron'} ,{"$set" :{'companyName': 'pwskills'}} )

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('63ef080c4d1367f0ea41c25b'), 'name': 'sudh', 'class': 'data science masters ', 'timing ': 'flexi'}
# {'_id': ObjectId('63ef08cc4d1367f0ea41c25c'), 'mail_id': 'sudh@gmail.com', 'phone_number': 2343243242}
# {'_id': ObjectId('63ef09484d1367f0ea41c25d'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('63ef09904d1367f0ea41c25e'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('63ef09904d1367f0ea41c25f'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('63ef09904d1367f0ea41c260'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('63ef09904d1367f0ea41c261'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('63ef09904d1367f0ea41c262'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('63ef09904d1367f0ea41c263'), 'name': 'Richard', 'address': 'Sky st 331'}
# ...

# %%
coll_create.drop()

# %%
for i in coll_create.find():
    print(i)
